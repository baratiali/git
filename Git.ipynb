# %% [markdown]
# # Git

# %% [markdown]
# `git inint`
#
# `ls -ltrha .git`: see the directories
#
# `git status`
#
# `git log`: shows the logs
#
# `git add "page*`: add all the files with name page (page1 , page2, ...)
#
#
# `git diff HEAD`: [explains the diffrence](https://www.atlassian.com/de/git/tutorials/saving-changes/git-diff)
#
# `git diff --staged`: show what changed in files the in stage are
#
# `git reset page3.html`
#
# `git checkout --page3.html`: revert it to the last changed
#
# `git brnach branchname`: creating a new branch
#
# `git branche`: shows list of the branches
#
# `git checkout branchname`: change the branch to the other one
#
# `git merg subbranchname`: merges the subbranch to master branch
#
# `git rm filename`: delet it from filesystem and git
#
# `git branch -d branch name`: delete a branch
#
# ## Adding files to an existing repository
#
# ```
# git remote init
#
# git remote add origin https://github.com/.....
#
# git remote
#
# git push -u origin master
#
# ```
# ---------
#
# `git show 2c0c411f1e950d0bdb770cf4c6ce8087778fd080`: show commit detail
#
# ---------
# ### [tag](https://git-scm.com/book/en/v2/Git-Basics-Tagging)
#
# `git tag -a v2.0 -m "second version `: put tags in project
#
# `git tag -a v1.0 2c0c411f1e950d0bd `: put tags to older commits
#
# `git tag -l "v*"`: Shows all tages start with V
#
# `git show v1.0`
#
# `git push origin v2.0`: How to push a tag
#
# `git push origin --tags`: How to push all tags
#
# `git checkout v1.0`: but its not like a branch

# %% [markdown]
# ### [gpg](https://blog.ghostinthemachines.com/2015/03/01/how-to-use-gpg-command-line/)

# %% [markdown]
# ` git config --global user.name  `
#
# ` git config --global user.email`
#
# `gpg --gen-key `
#
# ` gpg --list-keys `
#
# `gpg --list-`
#
# `gpg --list-secret-keys --keyid-format LONG`
#
# `git config --global user.signinkey 3C84C7C3120FA345`
#
# for example `git tag -s v2.0 -m "second version `: for tagging wtih your key
#
# `git tag -v v2.1`: verify
#
# `git commit -S -m ""`: key commit
#
# `git help commadn `: help

# %% [markdown]
# ### blame

# %% [markdown]
# `git blame Git.ipynb -L8`: find out who changed the programm (line 9)

# %% [markdown]
# ### to find bad version

# %% [markdown]
# `git bisect start`
